# %%
from flax import nnx
import jax
import jax.numpy as jnp
import optax

# %%
class MyModel(nnx.Module):
  def __init__(self, inSize: int, outSize: int, *, rngs: nnx.Rngs):
    intermediateSize = 64
    key = rngs.params()
    self.linear1 = nnx.Linear(inSize, intermediateSize, rngs=rngs)
    self.linear2 = nnx.Linear(intermediateSize, outSize, rngs=rngs)

  def __call__(self, x):
    x = self.linear1(x)
    x = jax.nn.relu(x)
    x = self.linear2(x)
    return x

# %%
rngs = nnx.Rngs(jax.random.key(0))
model = MyModel(2, 38, rngs=rngs)
tx = optax.adam(1e-3)
optimizerState = nnx.Optimizer(model, tx)
modelGraph, modelWeights = nnx.split(model)
del model

# %%
def lossFunction(model, x, index, target):
  values = model(x)
  return jnp.mean((values[index] - target) ** 2)

# %%
tmpModel = nnx.merge(modelGraph, modelWeights)
input = jnp.array([0.1, -0.1])
originalModelOutput = tmpModel(input)
print(f'Original model output: {originalModelOutput}')
index = 0
target = 1.0
loss = lossFunction(tmpModel, input, index, target)
print(f'Loss: {loss}')
del tmpModel
# Out:
# Original model output: [-0.03245787 -0.00417501 -0.05088333  0.06116954  0.08806434 -0.05966324
#  -0.10697126  0.00481742  0.0847846  -0.15256187 -0.07400742  0.03143728
#   0.03714191  0.01746072 -0.08262251  0.04910205 -0.04121367  0.06232316
#   0.08703245 -0.07444818  0.01227359  0.07393724 -0.14987452 -0.06048569
#  -0.09122576 -0.04660274 -0.07468466 -0.03908684  0.00765305 -0.04118071
#   0.0709928  -0.06787866 -0.04932142 -0.07135013  0.02210368 -0.02094354
#  -0.00290814  0.06492181]
# Loss: 1.0659691095352173

# %%
for i in range(100):
  tmpModel = nnx.merge(modelGraph, modelWeights)
  gradients = nnx.grad(lossFunction)(tmpModel, input, index, target)
  optimizerState.update(gradients)
  updatedModelOutput = tmpModel(input)
  # print(f'Updated model output: {updatedModelOutput}')
  newLoss = lossFunction(tmpModel, input, index, target)
  print(f'New loss: {newLoss}')
  del tmpModel

print(f'New model output: {tmpModel(input)}')
# Out:
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# New loss: 1.0659691095352173
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 for i in range(100):
#       2   tmpModel = nnx.merge(modelGraph, modelWeights)
# ----> 3   gradients = nnx.grad(lossFunction)(tmpModel, input, index, target)
#       4   optimizerState.update(gradients)
#       5   updatedModelOutput = tmpModel(input)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/flax/nnx/graph.py:1832, in UpdateContextManager.__call__.<locals>.update_context_manager_wrapper(*args, **kwargs)
#    1829 @functools.wraps(f)
#    1830 def update_context_manager_wrapper(*args, **kwargs):
#    1831   with self:
# -> 1832     return f(*args, **kwargs)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/flax/nnx/transforms/autodiff.py:165, in _grad_general.<locals>.grad_wrapper(***failed resolving arguments***)
#     152 pure_args = extract.to_tree(
#     153   args, prefix=arg_filters, split_fn=_grad_split_fn, ctxtag='grad'
#     154 )
#     156 gradded_fn = transform(
#     157   GradFn(f, has_aux, nondiff_states),
#     158   argnums=jax_argnums,
#    (...)
#     162   reduce_axes=reduce_axes,
#     163 )
# --> 165 fn_out = gradded_fn(*pure_args)
#     167 def process_grads(grads):
#     168   return jax.tree.map(
#     169     lambda x: x.state if isinstance(x, extract.NodeStates) else x,
#     170     grads,
#     171     is_leaf=lambda x: isinstance(x, extract.NodeStates),
#     172   )
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api.py:405, in grad.<locals>.grad_f_aux(*args, **kwargs)
#     402 @wraps(fun, docstr=docstr, argnums=argnums)
#     403 @api_boundary
#     404 def grad_f_aux(*args, **kwargs):
# --> 405   (_, aux), g = value_and_grad_f(*args, **kwargs)
#     406   return g, aux
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api.py:472, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     470   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     471 else:
# --> 472   ans, vjp_py, aux = _vjp(
#     473       f_partial, *dyn_args, has_aux=True)
#     474 _check_scalar(ans)
#     475 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api.py:2022, in _vjp(fun, has_aux, *primals)
#    2020 else:
#    2021   flat_fun, out_aux_trees = flatten_fun_nokwargs2(fun, in_tree)
# -> 2022   out_primals, vjp, aux = ad.vjp(flat_fun, primals_flat, has_aux=True)
#    2023   out_tree, aux_tree = out_aux_trees()
#    2024 out_primal_avals = map(shaped_abstractify, out_primals)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:262, in vjp(traceable, primals, has_aux)
#     260   out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     261 else:
# --> 262   out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#     264 def unbound_vjp(pvals, jaxpr, consts, *cts):
#     265   cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:245, in linearize(traceable, *primals, **kwargs)
#     243 _, in_tree = tree_flatten(((primals, primals), {}))
#     244 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 245 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     246 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     247 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:576, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     574 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     575 with core.set_current_trace(trace):
# --> 576   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     577   assert not env
#     578 del trace, fun
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/linear_util.py:210, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     208 def call_wrapped(self, *args, **kwargs):
#     209   """Calls the transformed function"""
# --> 210   return self.f_transformed(*args, **kwargs)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:590, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     582 @lu.transformation2
#     583 def trace_to_subjaxpr_nounits(
#     584     f: Callable,
#    (...)
#     587     debug_info: core.DebugInfo,
#     588     in_pvals: Sequence[PartialVal]):
#     589   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 590   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     591       f, trace, instantiate, in_pvals, debug_info)
#     592   out_pvals = [t.pval for t in out_tracers]
#     593   del out_tracers
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:623, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     621 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     622 with core.set_current_trace(trace):
# --> 623   ans = f(*in_args)
#     624 assert isinstance(ans, (list, tuple)), (
#     625     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     626 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     627     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:80, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      77 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      78        else contextlib.nullcontext())
#      79 with ctx:
# ---> 80   out_primals, out_tangents = f(tag, primals, tangents)
#      81 if type(instantiate) is bool:
#      82   instantiate = [instantiate] * len(out_tangents)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:129, in jvp_subtrace_aux(f, store, tag, primals, tangents)
#     127 trace = JVPTrace(parent_trace, tag)
#     128 with core.set_current_trace(trace):
# --> 129   ans, aux = f(*(map(partial(maybe_jvp_tracer, trace), primals, tangents)))
#     130 out_primals, out_tangents = unzip2(map(trace.to_primal_tangent_pair, ans))
#     131 aux_primals = [x.primal if isinstance(x, JVPTracer) and x._trace.tag is tag
#     132                else x for x in aux]
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api_util.py:106, in flatten_fun_nokwargs2(f, store, in_tree, *args_flat)
#     103 @lu.transformation_with_aux2
#     104 def flatten_fun_nokwargs2(f, store, in_tree, *args_flat):
#     105   py_args = tree_unflatten(in_tree, args_flat)
# --> 106   pair = f(*py_args)
#     107   if not isinstance(pair, (list, tuple)) or len(pair) != 2:
#     108     raise TypeError("expected function with aux output to return a two-element "
#     109                     f"tuple, but got type {type(pair)} with value {pair!r}")
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api_util.py:284, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     282 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     283 assert next(fixed_args_, sentinel) is sentinel
# --> 284 return _fun(*args, **kwargs)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/linear_util.py:388, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     386 @transformation_with_aux2
#     387 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 388   ans = _fun(*args, **kwargs)
#     389   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     390   if _store:
#     391     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     392     # the bwd function in a custom_vjp
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/flax/nnx/transforms/autodiff.py:88, in GradFn.__call__(self, *pure_args)
#      82     return ctx.merge(value.graphdef, value.state, nondiff)
#      84 args = extract.from_tree(
#      85   pure_args, merge_fn=_grad_merge_fn, ctxtag='grad', is_inner=True
#      86 )
# ---> 88 out = self.f(*args)
#      90 args_out = extract.clear_non_graph_nodes(args)
#      91 pure_args_out, pure_out = extract.to_tree((args_out, out), ctxtag='grad')
#
# Cell In[25], line 2, in lossFunction(model, x, index, target)
#       1 def lossFunction(model, x, index, target):
# ----> 2   values = model(x)
#       3   return jnp.mean((values[index] - target) ** 2)
#
# Cell In[23], line 9, in MyModel.__call__(self, x)
#       8 def __call__(self, x):
# ----> 9   x = self.linear1(x)
#      10   x = jax.nn.relu(x)
#      11   x = self.linear2(x)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/flax/nnx/nn/linear.py:377, in Linear.__call__(self, inputs)
#     375 assert self.use_bias == (bias is not None)
#     376 if bias is not None:
# --> 377   y += jnp.reshape(bias, (1,) * (y.ndim - 1) + (-1,))
#     378 return y
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     178   raise NotImplementedError(f"where argument of {self}")
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 1 frame]
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/pjit.py:340, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     335 if config.no_tracing.value:
#     336   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     337                      "`jit`, but 'no_tracing' is set")
#     339 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 340  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     342 maybe_fastpath_data = _get_fastpath_data(
#     343     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     344     jaxpr.consts, jit_info.abstracted_axes,
#     345     pgle_profiler)
#     347 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/pjit.py:180, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     179 def _python_pjit_helper(fun: Callable, jit_info: PjitInfo, *args, **kwargs):
# --> 180   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     182   for arg in args_flat:
#     183     dispatch.check_arg(arg)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/pjit.py:712, in _infer_params(fun, ji, args, kwargs)
#     709   resource_env = None
#     710   pjit_mesh = None
# --> 712 dbg = debug_info(
#     713     'jit', fun, args, kwargs, static_argnums=ji.static_argnums,
#     714     static_argnames=ji.static_argnames, sourceinfo=ji.fun_sourceinfo,
#     715     signature=ji.fun_signature)
#     717 if config.dynamic_shapes.value:  # if dynamic shapes, don't use the cache
#     718   p, args_flat = _infer_params_impl(fun, ji, pjit_mesh, resource_env, dbg,
#     719                                     args, kwargs, in_avals=None)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api_util.py:612, in debug_info(traced_for, fun, args, kwargs, static_argnums, static_argnames, result_paths_thunk, sourceinfo, signature)
#     610 if signature is None:
#     611   signature = fun_signature(fun)
# --> 612 arg_names = _non_static_arg_names(signature, args, kwargs, static_argnums,
#     613                                   static_argnames)
#     614 return core.DebugInfo(traced_for, sourceinfo, arg_names, result_paths_thunk)
#
# File ~/venv/hyperbot/lib/python3.10/site-packages/jax/_src/api_util.py:662, in _non_static_arg_names(fn_signature, args, kwargs, static_argnums, static_argnames)
#     658       return m.group(1)
#     659     return "<unknown>"
# --> 662 def _non_static_arg_names(fn_signature: inspect.Signature | None,
#     663                           args: Sequence[Any], kwargs: dict[str, Any],
#     664                           static_argnums: Sequence[int],
#     665                           static_argnames: Sequence[str],
#     666                           ) -> tuple[str, ...]:
#     667   """Returns the names of the non-static arguments.
#     668
#     669   If the `fn_signature` is given then we get from it the names of the
#     670   top-level arguments. In other cases, including when the `args` and `kwargs`
#     671   do not match the signature, we use names like `args[0[]`, `args[1]`, etc.
#     672   """
#     673   static = object()
#
# KeyboardInterrupt:
